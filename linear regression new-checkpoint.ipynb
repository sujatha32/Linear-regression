# %%
import pandas as pd

# %%
import numpy as np
import sklearn as sk

# %%
bostondata = pd.read_csv("train.csv")
bostondata
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
x = bostondata.drop(["SalePrice"],axis = 1)
y = bostondata[["SalePrice"]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,random_state=12121)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1314, 80), (146, 80), (1314, 1), (146, 1))

# %%
bostondata.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
bostondatacategorical = x_train.select_dtypes(object)
bostondataNumerical = x_train.select_dtypes(np.number)

# %%
bostondatacategorical.isna().sum()
# Out:
# MSZoning            0
# Street              0
# Alley            1230
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           34
# BsmtCond           34
# BsmtExposure       35
# BsmtFinType1       34
# BsmtFinType2       34
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          0
# KitchenQual         0
# Functional          0
# FireplaceQu       629
# GarageType         69
# GarageFinish       69
# GarageQual         69
# GarageCond         69
# PavedDrive          0
# PoolQC           1308
# Fence            1052
# MiscFeature      1262
# SaleType            0
# SaleCondition       0
# dtype: int64

# %%
bostondata.shape
# Out:
# (1460, 81)

# %%
bostondatacategorical.drop(["MiscFeature","Fence","PoolQC","Alley"],axis = 1, inplace = True)
# Out:
# C:\Users\sujatha\Downloads\anaconda\envs\Test\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
bostondatacategorical.isna().sum()
# Out:
# MSZoning           0
# Street             0
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         8
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual          34
# BsmtCond          34
# BsmtExposure      35
# BsmtFinType1      34
# BsmtFinType2      34
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         0
# KitchenQual        0
# Functional         0
# FireplaceQu      629
# GarageType        69
# GarageFinish      69
# GarageQual        69
# GarageCond        69
# PavedDrive         0
# SaleType           0
# SaleCondition      0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
sImputer = SimpleImputer

# %%
sImputer = SimpleImputer(strategy = 'most_frequent')

# %%
sImputer.fit(bostondatacategorical)
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
temp = sImputer.transform(bostondatacategorical)
bostondatacategoricalNARemoved = pd.DataFrame(temp,columns=bostondatacategorical.columns)

# %%
sImputerNumerical = SimpleImputer(strategy = "mean")

# %% [markdown]
# sImputerNumerical.fit(bostondataNumerical)

# %%
sImputerNumerical.fit(bostondataNumerical)
# Out:
# SimpleImputer()

# %%
temp = sImputerNumerical.transform(bostondataNumerical)
bostondataNumericalNARemoved = pd.DataFrame(temp,columns=bostondataNumerical.columns)

# %%
bostondata = pd.read_csv("train.csv")
bostondata
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
bostondatacategoricalEncoded = bostondatacategoricalNARemoved.apply(le.fit_transform)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

# %%
ss.fit(bostondataNumericalNARemoved)
# Out:
# StandardScaler()

# %%
temp = ss.transform(bostondataNumericalNARemoved)
bostondataNumericalEncoded = pd.DataFrame(temp,columns=bostondataNumericalNARemoved.columns)

# %%
bostondataNumericalEncoded.head()
# Out:
#          Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# 0 -1.519334    2.437913    -1.354319 -0.644964    -0.068181    -0.523667
# 1 -0.318226   -0.871525     0.791999 -0.245268    -0.802524     0.366499
# 2 -0.405881   -0.162360    -0.460020  0.056556    -1.536867     0.366499
# 3  0.172167   -0.635137    -1.354319 -0.560948    -1.536867     1.256666
# 4 -0.917596   -0.871525    -0.460020 -0.204695    -1.536867    -1.413834
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  GarageArea  \
# 0   1.267013      1.184239   -0.150313   -0.984225  ...    0.271460
# 1   0.135183     -0.467352   -0.575832   -0.984225  ...   -0.897024
# 2  -1.695719     -1.681756   -0.575832    0.407734  ...    0.469349
# 3  -1.828875      0.261291   -0.575832   -0.553745  ...   -0.143163
# 4  -0.697045     -1.681756   -0.575832   -0.984225  ...   -0.831061
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0   -0.747456     2.868186      -0.357724  -0.113719     -0.27116 -0.066914
# 1   -0.747456    -0.696898      -0.357724  -0.113719     -0.27116 -0.066914
# 2   -0.747456     0.019166       1.573392  -0.113719     -0.27116 -0.066914
# 3   -0.747456    -0.696898      -0.357724  -0.113719     -0.27116 -0.066914
# 4    1.245670    -0.696898       0.028499  -0.113719     -0.27116 -0.066914
#
#     MiscVal    MoSold    YrSold
# 0 -0.091066 -0.123179  0.897073
# 1 -0.091066 -0.860568  0.147706
# 2 -0.091066  0.982905 -1.351027
# 3 -0.091066  0.245516 -0.601661
# 4 -0.091066  0.982905  0.897073
#
# [5 rows x 37 columns]

# %%
bostondataFinal = pd.concat([bostondatacategoricalEncoded,bostondataNumericalEncoded],axis = 1)

# %%
from sklearn.linear_model import LinearRegression, SGDRegressor
lr = LinearRegression()
sgdR = SGDRegressor()

# %%
lr.fit(bostondataFinal.to_numpy(),y_train.to_numpy())
# Out:
# LinearRegression()
