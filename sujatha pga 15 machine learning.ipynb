# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\sujatha'

# %%
data=pd.read_csv(r'C:\\Users\\sujatha\desktop\sujatha\Dressify Test.csv')

# %%
stat=pd.read_csv(r'C:\\Users\\sujatha\desktop\sujatha\Dressify Train.csv')

# %%
data["Recommended"]='Test'

# %%
dataFinal=pd.concat([data,stat])
dataFinal
# Out:
#          ID    Style    Price  Rating  Size  Season        NeckLine  \
# 0    100345  vintage  Average     4.5     L  Automn          o-neck
# 1    100347   Casual      low     0.0  free  Spring          v-neck
# 2    100350   Casual  Average     0.0  free  Spring          o-neck
# 3    100357   Casual   Medium     0.0     S  Spring          v-neck
# 4    100358   Casual      Low     0.0  free     NaN          o-neck
# ..      ...      ...      ...     ...   ...     ...             ...
# 354  100839     Sexy   Medium     0.0  free  winter          o-neck
# 355  100840   Casual  Average     4.5     M  Winter          v-neck
# 356  100841   Casual      low     4.4  free  Summer  turndowncollor
# 357  100842   Casual  Average     5.0     L  Summer          o-neck
# 358  100843   Casual  Average     4.8     M  Summer          o-neck
#
#      SleeveLength waiseline  Material FabricType Decoration Pattern Type Area  \
# ...

# %%
dataFinal.head()
# Out:
#        ID    Style    Price  Rating  Size  Season NeckLine  SleeveLength  \
# 0  100345  vintage  Average     4.5     L  Automn   o-neck     sleevless
# 1  100347   Casual      low     0.0  free  Spring   v-neck  threequarter
# 2  100350   Casual  Average     0.0  free  Spring   o-neck     sleevless
# 3  100357   Casual   Medium     0.0     S  Spring   v-neck          full
# 4  100358   Casual      Low     0.0  free     NaN   o-neck          full
#
#   waiseline Material FabricType Decoration Pattern Type Area Recommended  \
# 0    empire      NaN    worsted        NaN        solid    B        Test
# 1       NaN     silk        NaN       lace          NaN    D        Test
# 2   natural      NaN    chiffon        NaN        solid    A        Test
# 3       NaN      NaN        NaN        NaN       animal    A        Test
# 4   natural   cotton        NaN        NaN    patchwork    E        Test
#
#    Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18
# ...

# %% [markdown]
# # head,tail,shape,describe

# %%
dataFinal.tail()
# Out:
#          ID   Style    Price  Rating  Size  Season        NeckLine  \
# 354  100839    Sexy   Medium     0.0  free  winter          o-neck
# 355  100840  Casual  Average     4.5     M  Winter          v-neck
# 356  100841  Casual      low     4.4  free  Summer  turndowncollor
# 357  100842  Casual  Average     5.0     L  Summer          o-neck
# 358  100843  Casual  Average     4.8     M  Summer          o-neck
#
#     SleeveLength waiseline  Material FabricType Decoration Pattern Type Area  \
# 354    sleevless   natural  polyster        NaN   sequined        solid    A
# 355    sleevless   natural       NaN    chiffon     button      striped    C
# 356    sleevless   natural    cotton        NaN        NaN        solid    E
# 357    sleevless   natural    cotton        NaN        NaN          NaN    A
# 358   halfsleeve       NaN       NaN        NaN        NaN          NaN    B
#
#     Recommended  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18
# ...

# %%
dataFinal.shape
# Out:
# (500, 19)

# %%
dataFinal.dtypes
# Out:
# ID                int64
# Style            object
# Price            object
# Rating          float64
# Size             object
# Season           object
# NeckLine         object
# SleeveLength     object
# waiseline        object
# Material         object
# FabricType       object
# Decoration       object
# Pattern Type     object
# Area             object
# Recommended      object
# Unnamed: 15     float64
# Unnamed: 16     float64
# Unnamed: 17     float64
# Unnamed: 18     float64
# dtype: object

# %%
dataFinal.describe()
# Out:
#                   ID      Rating  Unnamed: 15  Unnamed: 16  Unnamed: 17  \
# count     500.000000  500.000000          0.0          0.0          0.0
# mean   100594.500000    3.528600          NaN          NaN          NaN
# std       144.481833    2.005364          NaN          NaN          NaN
# min    100345.000000    0.000000          NaN          NaN          NaN
# 25%    100469.750000    3.700000          NaN          NaN          NaN
# 50%    100594.500000    4.600000          NaN          NaN          NaN
# 75%    100719.250000    4.800000          NaN          NaN          NaN
# max    100844.000000    5.000000          NaN          NaN          NaN
#
#        Unnamed: 18
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
dataFinal.columns
# Out:
# Index(['ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern Type', 'Area', 'Recommended', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18'],
#       dtype='object')

# %%
dataFinal["Style"].value_counts()
dataFinal["Price"].value_counts()
dataFinal["Season"].value_counts()
dataFinal["NeckLine"].value_counts()
dataFinal["SleeveLength"].value_counts()
# Out:
# sleevless         223
# full               97
# short              96
# halfsleeve         35
# threequarter       17
# thressqatar        10
# sleeveless          5
# capsleeves          3
# sleeevless          3
# cap-sleeves         2
# Petal               1
# turndowncollor      1
# urndowncollor       1
# sleveless           1
# threequater         1
# butterfly           1
# half                1
# Name: SleeveLength, dtype: int64

# %%
dataFinal.isnull().sum()
# Out:
# ID                0
# Style             0
# Price             2
# Rating            0
# Size              0
# Season            2
# NeckLine          3
# SleeveLength      2
# waiseline        87
# Material        128
# FabricType      266
# Decoration      236
# Pattern Type    109
# Area              0
# Recommended       0
# Unnamed: 15     500
# Unnamed: 16     500
# Unnamed: 17     500
# Unnamed: 18     500
# dtype: int64

# %%
dataFinal.drop(['Unnamed: 18','Unnamed: 17','Unnamed: 16','Unnamed: 15'],axis=1,inplace=True)

# %% [markdown]
# # CROSS TAB

# %%
pd.crosstab(dataFinal.Price,dataFinal.Style)
# Out:
# Style      Brief  Casual  Flare  Novelty  OL  Sexy  bohemian  cute  fashion  \
# Price
# Average       13     118      2        7   0    29        10    21        1
# High           0       1      0        0   0     0         0     2        0
# Low            5      70      0        0   0    24        11    12        0
# Medium         0      12      0        1   1     2         1     4        0
# high           0       5      0        0   0     1         0     1        0
# low            0      24      0        0   0    12         1     5        0
# very-high      0       2      0        0   0     1         1     0        0
#
# Style      party  sexy  vintage  work
# Price
# Average       18     2       17    14
# High           1     0        2     0
# Low            0     4        3     0
# Medium         5     1        2     1
# high           8     0        0     0
# low            0     0        1     2
# very-high     17     0        0     0

# %%
pd.crosstab(dataFinal.Size,dataFinal.Style)
# Out:
# Style  Brief  Casual  Flare  Novelty  OL  Sexy  bohemian  cute  fashion  \
# Size
# L          3      46      0        1   0     9         4    11        0
# M          7      74      0        2   1    18         4    18        0
# S          0      19      0        1   0     8         1     1        0
# XL         2      10      0        0   0     0         1     2        0
# free       6      81      2        4   0    34        14    13        1
# s          0       1      0        0   0     0         0     0        0
# small      0       1      0        0   0     0         0     0        0
#
# Style  party  sexy  vintage  work
# Size
# L          8     2        7     5
# M         32     5        7     9
# S          2     0        4     1
# XL         0     0        0     0
# free       9     0        7     2
# s          0     0        0     0
# small      0     0        0     0

# %%
pd.crosstab(dataFinal.Season,dataFinal.FabricType)
# Out:
# FabricType  Corduroy  batik  broadcloth  chiffon  dobby  flannael  flannel  \
# Season
# Automn             0      0           3       20      1         0        0
# Autumn             0      0           0        2      0         0        0
# Spring             0      0           5       43      1         0        0
# Summer             2      2          11       31      0         0        0
# Winter             0      0           6       30      0         1        1
# spring             0      0           0        1      0         0        0
# winter             0      0           6        8      0         0        0
#
# FabricType  jersey  knitted  knitting  ...  other  poplin  satin  sattin  \
# Season                                 ...
# Automn           0        0         0  ...      0       0      0       0
# Autumn           0        0         0  ...      0       0      0       1
# Spring           3        0         0  ...      0       0      1       2
# ...

# %%
pd.crosstab(dataFinal.Recommended,dataFinal.Price)
# Out:
# Price        Average  High  Low  Medium  high  low  very-high
# Recommended
# 0                115     2   50       5     6   23          5
# 1                 63     2   43      15     6   15          8
# Test              74     2   36      10     3    7          8

# %%
pd.crosstab(dataFinal.Recommended,dataFinal.Style)
# Out:
# Style        Brief  Casual  Flare  Novelty  OL  Sexy  bohemian  cute  fashion  \
# Recommended
# 0               10     103      0        4   1    31         7    15        0
# 1                3      66      1        2   0    20        11    18        0
# Test             5      63      1        2   0    18         6    12        1
#
# Style        party  sexy  vintage  work
# Recommended
# 0               12     2       13     8
# 1               21     3        5     3
# Test            18     2        7     6

# %% [markdown]
# # chi square test

# %%
from scipy.stats import chi2_contingency

# %%
chi2_contingency(pd.crosstab(dataFinal.Style,
                            dataFinal.Recommended))
# Since p-value=0.4545454453451022 is greater than 0.05, Fail to Reject null
# Out:
# (24.123643260383172,
#  0.4545454453451022,
#  24,
#  array([[ 7.416,  5.508,  5.076],
#         [95.584, 70.992, 65.424],
#         [ 0.824,  0.612,  0.564],
#         [ 3.296,  2.448,  2.256],
#         [ 0.412,  0.306,  0.282],
#         [28.428, 21.114, 19.458],
#         [ 9.888,  7.344,  6.768],
#         [18.54 , 13.77 , 12.69 ],
#         [ 0.412,  0.306,  0.282],
#         [21.012, 15.606, 14.382],
#         [ 2.884,  2.142,  1.974],
#         [10.3  ,  7.65 ,  7.05 ],
#         [ 7.004,  5.202,  4.794]]))

# %% [markdown]
# # dataFinal is dividing categorical and numerical

# %%
dataFinalCategorical = dataFinal.select_dtypes(object)
dataFinalNumerical = dataFinal.select_dtypes(np.number)

# %%
dataFinalNumerical['Recommended']=dataFinalCategorical.Recommended
# Out:
# <ipython-input-74-89285d993bb8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFinalNumerical['Recommended']=dataFinalCategorical.Recommended

# %%
dataFinalCategorical.drop(['Recommended'],axis=1,inplace=True)
# Out:
# C:\Users\sujatha\Downloads\anaconda\envs\Test\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dataFinalNumerical.columns
# Out:
# Index(['ID', 'Rating', 'Recommended'], dtype='object')

# %%
for col in dataFinalCategorical.columns:
    dataFinalCategorical[col] = dataFinalCategorical[col].fillna(dataFinalCategorical[col].value_counts().idxmax())
# Out:
# <ipython-input-77-0de70ccc0d6d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFinalCategorical[col] = dataFinalCategorical[col].fillna(dataFinalCategorical[col].value_counts().idxmax())

# %%
dataFinalCategorical
# Out:
#        Style    Price  Size  Season        NeckLine  SleeveLength waiseline  \
# 0    vintage  Average     L  Automn          o-neck     sleevless    empire
# 1     Casual      low  free  Spring          v-neck  threequarter   natural
# 2     Casual  Average  free  Spring          o-neck     sleevless   natural
# 3     Casual   Medium     S  Spring          v-neck          full   natural
# 4     Casual      Low  free  Summer          o-neck          full   natural
# ..       ...      ...   ...     ...             ...           ...       ...
# 354     Sexy   Medium  free  winter          o-neck     sleevless   natural
# 355   Casual  Average     M  Winter          v-neck     sleevless   natural
# 356   Casual      low  free  Summer  turndowncollor     sleevless   natural
# 357   Casual  Average     L  Summer          o-neck     sleevless   natural
# 358   Casual  Average     M  Summer          o-neck    halfsleeve   natural
#
#      Material FabricType Decoration Pattern Type Area
# ...

# %% [markdown]
# # DATA PROCESSING

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dataFinalCategoricalEncoder = dataFinalCategorical.apply(le.fit_transform)

# %%
dataFinalNumerical
# Out:
#          ID  Rating Recommended
# 0    100345     4.5        Test
# 1    100347     0.0        Test
# 2    100350     0.0        Test
# 3    100357     0.0        Test
# 4    100358     0.0        Test
# ..      ...     ...         ...
# 354  100839     0.0           0
# 355  100840     4.5           0
# 356  100841     4.4           0
# 357  100842     5.0           1
# 358  100843     4.8           0
#
# [500 rows x 3 columns]

# %%
dataFinalCategoricalEncoder
# Out:
#      Style  Price  Size  Season  NeckLine  SleeveLength  waiseline  Material  \
# 0       11      0     0       0         7            10          1         3
# 1        1      5     4       2        15            12          2        18
# 2        1      0     4       2         7            10          2         3
# 3        1      3     2       2        15             4          2         3
# 4        1      2     4       3         7             4          2         3
# ..     ...    ...   ...     ...       ...           ...        ...       ...
# 354      5      3     4       7         7            10          2        15
# 355      1      0     1       4        15            10          2         3
# 356      1      5     4       3        14            10          2         3
# 357      1      0     0       3         7            10          2         3
# 358      1      0     1       3         7             6          2         3
#
# ...

# %%
datanew1 = pd.concat([dataFinalCategoricalEncoder,dataFinalNumerical],axis=1)

# %%
Traindf=datanew1[datanew1.Recommended!='Test']
Testdf=datanew1[datanew1.Recommended=='Test']

# %%
Traindf.dtypes
# Out:
# Style             int32
# Price             int32
# Size              int32
# Season            int32
# NeckLine          int32
# SleeveLength      int32
# waiseline         int32
# Material          int32
# FabricType        int32
# Decoration        int32
# Pattern Type      int32
# Area              int32
# ID                int64
# Rating          float64
# Recommended      object
# dtype: object

# %%
Testdf
# Out:
#      Style  Price  Size  Season  NeckLine  SleeveLength  waiseline  Material  \
# 0       11      0     0       0         7            10          1         3
# 1        1      5     4       2        15            12          2        18
# 2        1      0     4       2         7            10          2         3
# 3        1      3     2       2        15             4          2         3
# 4        1      2     4       3         7             4          2         3
# ..     ...    ...   ...     ...       ...           ...        ...       ...
# 136      7      5     0       3         7            10          2         3
# 137      5      2     4       2         7             4          2         3
# 138      5      0     0       0        15            10          1         3
# 139      7      2     1       3         3             7          2         3
# 140     12      0     1       4        11             7          2        15
#
# ...

# %%
Traindf['Rating']=Traindf.Rating.astype('int64')
# Out:
# <ipython-input-87-eaeccb51904c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Traindf['Rating']=Traindf.Rating.astype('int64')

# %%
Traindf['Recommended']=Traindf.Recommended.astype('int64')
# Out:
# <ipython-input-88-e2c1627e45d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Traindf['Recommended']=Traindf.Recommended.astype('int64')

# %% [markdown]
# # build the model

# %%
x = Traindf.drop(["Recommended"], axis=1)
y = Traindf[["Recommended"]]

# %% [markdown]
# # logistic regression

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()

# %%
Traindf.fillna(Traindf.mean(), inplace=True)
# Out:
# C:\Users\sujatha\Downloads\anaconda\envs\Test\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
Traindf.isna().sum()
# Out:
# Style           0
# Price           0
# Size            0
# Season          0
# NeckLine        0
# SleeveLength    0
# waiseline       0
# Material        0
# FabricType      0
# Decoration      0
# Pattern Type    0
# Area            0
# ID              0
# Rating          0
# Recommended     0
# dtype: int64

# %%
log.fit(x,y)
# Out:
# C:\Users\sujatha\Downloads\anaconda\envs\Test\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# LogisticRegression()

# %%
log.score(x,y)
# Out:
# 0.5738161559888579

# %%
logitpredict=log.predict(x)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y,logitpredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73       206
#            1       0.00      0.00      0.00       153
#
#     accuracy                           0.57       359
#    macro avg       0.29      0.50      0.36       359
# weighted avg       0.33      0.57      0.42       359
# C:\Users\sujatha\Downloads\anaconda\envs\Test\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\sujatha\Downloads\anaconda\envs\Test\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# # RandomForestRegressor score

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RF = RandomForestRegressor()

# %%
RFmodel  = RF.fit(x,y)
# Out:
# <ipython-input-101-fb8df2ef0207>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFmodel  = RF.fit(x,y)

# %%
RFmodel.score(x,y)
# Out:
# 0.8620837680055842

# %% [markdown]
# # GradientBoostingRegressor model

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gdm = GradientBoostingRegressor()

# %%
gdmmodel = gdm.fit(x,y)
# Out:
# C:\Users\sujatha\Downloads\anaconda\envs\Test\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
gdmmodel.score(x,y)
# Out:
# 0.6255296107110736

# %% [markdown]
# # DecisionTreeClassifier score

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()

# %%
treemodel = tree.fit(x,y)

# %%
treemodel.score(x,y)
# Out:
# 1.0

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(tree,x,y,cv=5)
# Out:
# array([0.5       , 0.47222222, 0.54166667, 0.56944444, 0.53521127])

# %% [markdown]
# # naive_bayes
# 1)GaussianNB
# 2)MultinomialNB

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB

# %%
gnb = GaussianNB() 
mnb = MultinomialNB()

# %%
gnb.fit(x,y)
# Out:
# C:\Users\sujatha\Downloads\anaconda\envs\Test\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# GaussianNB()

# %%
gnb.score(x,y)
# Out:
# 0.6211699164345403

# %%
mnb.fit(x,y)
# Out:
# C:\Users\sujatha\Downloads\anaconda\envs\Test\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# MultinomialNB()

# %% [markdown]
# # support vector machine

# %%
from sklearn.svm import SVC

# %%
sm=SVC()

# %%
smmodel=sm.fit(x,y)
# Out:
# C:\Users\sujatha\Downloads\anaconda\envs\Test\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
svmpredict = smmodel.predict(x)

# %%
print(classification_report(y,svmpredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73       206
#            1       0.00      0.00      0.00       153
#
#     accuracy                           0.57       359
#    macro avg       0.29      0.50      0.36       359
# weighted avg       0.33      0.57      0.42       359
# C:\Users\sujatha\Downloads\anaconda\envs\Test\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\sujatha\Downloads\anaconda\envs\Test\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# # Multilayer prediction

# %%
from sklearn.neural_network import MLPClassifier

# %%
nn=MLPClassifier()

# %%
nnmodel=nn.fit(x,y)
# Out:
# C:\Users\sujatha\Downloads\anaconda\envs\Test\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
nnpredict=nnmodel.predict(x)

# %%
print(classification_report(y,nnpredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73       206
#            1       0.00      0.00      0.00       153
#
#     accuracy                           0.57       359
#    macro avg       0.29      0.50      0.36       359
# weighted avg       0.33      0.57      0.42       359
# C:\Users\sujatha\Downloads\anaconda\envs\Test\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\sujatha\Downloads\anaconda\envs\Test\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
